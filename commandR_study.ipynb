# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cohere
co = cohere.Client('')

# %%
response=co.chat(
  model="command-r",
  message="Écris une description de produit pour une voiture électrique en 50 à 75 mots"
)
intro_paragraph = response.text

# %%
intro_paragraph
# Out:
# "Cette voiture électrique innovante offre une expérience de conduite sans précédent. Avec une autonomie impressionnante et un temps de recharge rapide, elle est l'option parfaite pour les conducteurs écologiques. Ses moteurs puissants assurent une conduite fluide et silencieuse, tandis que son design élégant et aérodynamique attire tous les regards. Découvrez la conduite de demain avec cette voiture électrique révolutionnaire !"
